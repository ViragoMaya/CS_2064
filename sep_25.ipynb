# %%
if True == 2: 
    print ( 'True == 1')
elif False == 0:
    print('False == 0 ')
# Out:
# False == 0

# %%
import math

# %%
math.pi 
math.e
math.sqrt(4)
#these are methods
name =  "Hokie"
# casues error bc name is not a library but it is an object
#strings dont have bi attribute -- one atrtibute is upper. 
name.upper()
lst - [3, 1, 4, 1]
lst.append(5)
class myMath:
    def __init__(self):
        self.pi = 3.121592653
    def sqrt (self,num):
        return 42
    m = myMath()
    m.pi
    m.sqrt(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6 # casues error bc name is not a library but it is an object
#       7 #strings dont have bi attribute -- one atrtibute is upper.
#       8 name.upper()
# ----> 9 lst - [3, 1, 4, 1]
#      10 lst.append(5)
#      11 class myMath:
#
# NameError: name 'lst' is not defined
