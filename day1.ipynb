# %%
import math

# %%
# // , %, +, - , *, **, /, ^ !(not/negation)
12/6 * 3

#multiplication and division have higher precedence(mult and divid have the same precedence)than addition and subtraction
12 + 6 / 3
12 * 2/36


##    KNOW THE ORDER OF OPERATIONS
###


#floor division (//) - rounds down to the nearest whole number or rather truncates the decimal
#truncation: ignores the decimal part -- in a computer, zero can be positive or negative
-1//2
#here it rounds down to next whole number^
#For negative numbers, floor division always rounds down (towards negative infinity)
#(since -0.5 floors to -1, not 0)

print(f' -1//2 = {-1//2}')
print(f' 1//-2 = {1//2}')

# use % to print the remainder or use % to deal with time. time is an integer. time 0 = jan 1 1970 - modulo operator can split time into days, hours, minutes, seconds
#data goes into api and api gives back time in seconds since jan 1 1970 - so use modulo to convert it into days, hours, minutes, seconds
# if you want to test a number if it's even or odd, use modulo
#even numbers % 2 = 0
#odd numbers % 2 = 1
#if you want to make anything secure you have to think about exchanging data securely - encryption algorithms use modulo
      

#dog is an instance(object) of (class)animal #object is an instance of a class
#class is a blueprint for an object



#bad to use input here bc as soon as you do input = something, you override the built-in function input()
#never want to use keyworkds as variable names
# Out:
#  -1//2 = -1
#  1//-2 = 0

# %%
user_input = str(input("enter ur name: ") ) #input function takes input from user as a string
print(f'hello {user_input}, {type (user_input)}')
# Out:
# hello ghazal, <class 'str'>
