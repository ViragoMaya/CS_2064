# %%
#match term to description

Object = an instance of a class
Class = a blueprint for creating objects
Attribute = a variable that belongs to an object or class
Method = a function that belongs to an object or class
Instance = a specific realization of a class
Module = a single file that contains O-n classes --  A module in Python is a single file containing Python code (e.g., functions, classes, variables). When you import a .py file, you are importing a module.
Package = a collection of related modules that share a name space (a logical contairs grouping related code elements, names resoc etc liek classes functs and variables to prevent naming conflicts. )-- u import packages liek math etc. 
Library = functional structure that is used for general purpose access from other languages(contains packages and modules)
    
Methods are functions internal to a class

not all methods change the internal state of a mutable object at all times
 example: list.sort() changes the internal state of a list, but str.upper() does not change the internal state of a string (strings are immutable in Python).
immutable = cannot be changed after creation

All packages are modules (of a specific type): 
When you import a package, Python creates a module object representing that package. 
This module object allows you to access its contents (sub-modules, sub-packages).

# %%
Question 1:
Which of the following statements is most accurate for the declaration x = Circle()?

Answer:
x contains a reference to a Circle object

Explanation:

In Python, when you write x = Circle(), you are creating a new instance of the Circle class.
The variable x does not store the object itself, but a reference (or pointer) to that object in memory.
The other options are incorrect:
"x contains an int value" (not true, x is not an int)
"x contains an object of the Circle type" (not precise, it's a reference)
"Circle contains an int type" (not relevant)

Question 2:
What will be the output of the following code snippet:

Python
class Sales:
    def __init__(self, id):
        self.id = id
        id = 100

val = Sales(123)
print(val.id)
Answer:
123

Explanation:

When creating Sales(123), the __init__ method assigns self.id = id, so self.id is set to 123.
The next line in __init__, id = 100, just reassigns the local variable id, but does not change self.id.
So, when you print val.id, you get 123

Question 3:
The correct way to instantiate the following class is:

Python
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age
Answer:
Dog("Rufus", 3)

Explanation:

The __init__ method expects two parameters: name and age.
Dog() would fail because it doesn’t provide those arguments.
Dog.create("Rufus", 3) is not valid unless you define a create class method.
Dog.__init__("Rufus", 3) is not how constructors are called in Python.
So, Dog("Rufus", 3) is correct.
