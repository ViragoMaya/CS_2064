# %% [markdown]
# # September 2
#     + Conditional Statements
#     + Conditional Operators
#     + Logical Operators
#     + Loops

# %% [markdown]
# #### Review % (mod) operator

# %%
import math 
import random

# %%
# ask the user how many students are in the class
user_input = int(input("How many students are in the class? "))
#print(f'you need {(user_input/2)} groups ')
# the math.ceil function rounds up to the nearest whole number
print(f'you need {math.ceil(user_input/2)} groups ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 2
#       1 # ask the user how many students are in the class
# ----> 2 user_input = int(input("How many students are in the class? "))
#       3 #print(f'you need {(user_input/2)} groups ')
#       4 # the math.ceil function rounds up to the nearest whole number
#       5 print(f'you need {math.ceil(user_input/2)} groups ')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# # create a last of students - #'s as a student 
# students = [ ]
# for i in range(1, 122):
#     students.append(i)
# print(students)

# create a list of students - #'s as a student 

students = [i for i in range(1, 123)]
# create a list of students - #'s as a student  -- memorize logic above^ look at cheat sheet u made last sem. 
students = random.sample(range(1,123), 122)
#group students into groups of 6
for student in students :
    print(f'{student} is in group {math.ceil(student% 21+1)}')
    #will always have groups greater than 1

# %%
# for i in range(0,5):
#     print("*" * 5)

for i in range(0,6):
     print("*" * i )
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# #### Conditional Statements

# %%
#details ab strings
name = 'turkey'
# name[0] = 't' -- error!
name_list = ['t', 'u', 'r', 'k', 'e', 'y']
name_list[0] = 'T'  # This will change the first element to 'T'
name_list[0]
# Out:
# 'T'

# %%
for letter in 'Python':
    if letter == 'h':
        print('turkey!') 
        continue#skips everythng below it and goes to next iteration
    
    print('Current Letter : ' + letter)
# Out:
# Current Letter : P
# Current Letter : y
# Current Letter : t
# turkey!
# Current Letter : o
# Current Letter : n

# %% [markdown]
# ### exploring for and while loops

# %%
for i in range(3):
    print(f' {i}: turkey')
    

count = 0
while (count < 3):
    print(f'{count}: turkey')
    count += 1
    #suited for when u dont know how many times u want to loop/iterate


guess = 0 
while(guess != 1):
    guess = int(input('guess a #:'))
# Out:
#  0: turkey
#  1: turkey
#  2: turkey
# 0: turkey
# 1: turkey
# 2: turkey

# %%
start = 1
end = 3
for i in range(start, end, -1): #start, stop, step -- the negative one makes it go backwards
    print(i)
    end += 1

    #start and end range is alrd set into memory so it wont change

# %% [markdown]
# ##### never change what ur looping over in ur for loop

# %%
# for i in range(1, 3):
#     print(i) # bts the comp decides to not print anything bc it sees that 3 is already greater than 1 so it wont even start the loop unless you step backwards (neg. number)
#     i -= 1

for letter in name_list:
    print(letter)
    name_list.append('turkey')
# Out:
# T
# u
# r
# k
# e
# y
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# turkey
# ...
